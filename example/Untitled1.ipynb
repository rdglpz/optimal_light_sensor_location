# %%
import numpy as np

import matplotlib.pyplot as plt

plt.style.use('ggplot')

from pprint import pprint

# %%
xx, yy = np.mgrid[0:0.5 * np.pi:500j, 0:0.8 * np.pi:500j]

np.random.seed(42)

# %%
_field = np.sin(xx)**2 + np.cos(yy)**2 + 10
z = _field + np.random.normal(0, 0.15, (500,  500))

# %%
plt.imshow(z, cmap='RdYlBu_r')

# %%
coords = np.random.randint(0, 500, (300, 2))

# %%
coords[:,1]
# Out:
# array([310, 204, 121, 260, 159,  99, 454, 459, 113, 126, 129, 192, 163,
#        372, 179,  88, 195, 252, 423, 398,   5, 495, 324, 178, 222, 347,
#        384, 404, 318,  85,  46, 160, 385,  74, 333,  50, 427,  11, 232,
#        362, 422,  93, 263,  72, 178, 325,  35, 173, 283, 458, 290, 418,
#        286, 279, 479,  16, 196, 182, 303, 340, 322, 237, 477, 140, 267,
#        176, 192, 473, 483, 261, 430, 257, 463, 103, 451, 241, 229, 290,
#        120, 105, 349,  19, 398,   6,  51, 395, 255,  17, 380, 372, 285,
#        331, 344, 374, 120, 101, 212, 355, 106, 207,  59, 111, 357,  13,
#        129, 215, 280,   2, 385, 355, 447, 299, 140, 462, 245,   1, 372,
#        244, 255,   0, 457,  82,  25, 189, 403, 292,  41, 404, 281, 294,
#        141, 185,  96, 300,  24,  57,  47,  45, 254, 349,  77, 325, 222,
#        409, 343, 263, 140, 430, 192, 484,  80, 245, 433, 359, 383, 292,
#        411, 466, 284, 426,  55, 358, 355, 316, 311,   5,  46, 326, 295,
#        248, 124, 135, 123, 261, 214, 227, 205, 212,  50, 352, 328, 300,
#        387, 252, 230,  47, 384, 212, 453, 336, 243, 172, 290, 370, 267,
#        353, 183, 204, 223, 425, 224, 413, 489, 108,  44, 168,  40, 119,
#        133, 440, 442, 294,  18, 461, 135, 316, 105,  26,  76, 431,  17,
#         69,  35, 294, 470, 234,   7,  34, 112, 423,  44, 202, 405, 339,
#        119, 378, 487,  43,  29, 304, 206, 476, 190,  71, 100, 284, 305,
#         43, 355,  51,  56, 428, 253, 414, 101,  53, 348,  36, 308, 138,
#         89, 149, 427, 181,  57, 370, 486, 346, 243, 201,   2,  50,  18,
#        187, 241, 306, 437, 146, 406,   1, 106, 227, 431, 459, 269, 225,
#        417,  87, 480, 110, 114, 397, 263,  35,  55,  68, 238,  67, 445,
#        254])
